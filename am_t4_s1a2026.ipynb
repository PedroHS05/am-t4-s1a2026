# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroHS05/am-t4-s1a2026/blob/main/am_t4_s1a2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução de Python

# %%
a=2
b=3
print('A soma é: ', a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ##Segunda Camada

# %%
c=4
d=5
print('A multiplicação é:', c*d)
# Out:
# A multiplicação é: 20

# %% [markdown]
# #Biblioteca e funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Numero sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# ##Testes de funções matematicas

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
for i in range(12):
  if(i % 2 == 0):
    if(eq[i] != 'Numero sem raiz'):
      print('X1: [', eq[i],']')
  else:
    if(eq[i] != 'Numero sem raiz'):
      print('X2: [', eq[i],']\n')
# Out:
# X1: [ 2.0 ]
# X2: [ 1.0 ]
#
# X2: [ -76 ]
#
# X1: [ 2.596291201783626 ]
# X2: [ -0.09629120178362593 ]
#
# X2: [ -7 ]
#
# X1: [ -0.10849528301415079 ]
# X2: [ 4.60849528301415 ]
#
# X1: [ -1.7807764064044151 ]
# X2: [ 0.28077640640441515 ]
